# %% [markdown]
# # An offline demo for the "Learning-based Video Motion Magnification" (ECCV 2018)
#
# # Official repo: https://github.com/12dmodel/deep_motion_mag
# # My repo: https://github.com/ZhengPeng7/motion_magnification_learning-based

# %% [markdown]
# ## Make sure to set your python Kernel for notebook.

# %% [markdown]
# ## Preparations:

# %% [markdown]
# ### Install python packages

# %%
# !pip install --quiet -r requirements.txt
# !pip install --quiet gdown mediapy
# Out:
# ⠀⠀⠀⠀⣀⡀
# ⠀⠀⠀⠀⣿⠙⣦⠀⠀⠀⠀⠀⠀⣀⣤⡶⠛⠁
# ⠀⠀⠀⠀⢻⠀⠈⠳⠀⠀⣀⣴⡾⠛⠁⣠⠂⢠⠇
# ⠀⠀⠀⠀⠈⢀⣀⠤⢤⡶⠟⠁⢀⣴⣟⠀⠀⣾
# ⠀⠀⠀⠠⠞⠉⢁⠀⠉⠀⢀⣠⣾⣿⣏⠀⢠⡇
# ⠀⠀⡰⠋⠀⢰⠃⠀⠀⠉⠛⠿⠿⠏⠁⠀⣸⠁
# ⠀⠀⣄⠀⠀⠏⣤⣤⣀⡀⠀⠀⠀⠀⠀⠾⢯⣀
# ⠀⠀⣻⠃⠀⣰⡿⠛⠁⠀⠀⠀⢤⣀⡀⠀⠺⣿⡟⠛⠁
# ⠀⡠⠋⡤⠠⠋⠀⠀⢀⠐⠁⠀⠈⣙⢯⡃⠀⢈⡻⣦
# ⢰⣷⠇⠀⠀⠀⢀⡠⠃⠀⠀⠀⠀⠈⠻⢯⡄⠀⢻⣿⣷
# ⠀⠉⠲⣶⣶⢾⣉⣐⡚⠋⠀⠀⠀⠀⠀⠘⠀⠀⡎⣿⣿⡇
# ⠀⠀⠀⠀⠀⣸⣿⣿⣿⣷⡄⠀⠀⢠⣿⣴⠀⠀⣿⣿⣿⣧
# ⠀⠀⠀⢀⣴⣿⣿⣿⣿⣿⠇⠀⢠⠟⣿⠏⢀⣾⠟⢸⣿⡇
# ⠀⠀⢠⣿⣿⣿⣿⠟⠘⠁⢠⠜⢉⣐⡥⠞⠋⢁⣴⣿⣿⠃
# ⠀⠀⣾⢻⣿⣿⠃⠀⠀⡀⢀⡄⠁⠀⠀⢠⡾ᵇʸ ᵗⁿᵏᵃ⠁
# ⠀⠀⠃⢸⣿⡇⠀⢠⣾⡇⢸⡇⠀⠀⠀⡞
# ⠀⠀⠀⠈⢿⡇⡰⠋⠈⠙⠂⠙⠢
# ⠀⠀⠀⠀⠈⢧
# Satwik@SHADOW
#
#  Windows 11 Home (25H2) aarch64
#  Snapdragon(R) X 10-core X1P64100 (10) @ 3.40 GHz
# 󰚗 Microsoft Surface Pro, 11th Edition
#  14.28 GiB / 15.61 GiB (92%)
#  349.22 GiB / 929.95 GiB (38%) - NTFS
#  378.26 GiB / 929.95 GiB (41%) - FAT32
#
# ● ● ● ● ● ● ● ●
#
#
#
#
#
#
#
#
#
# ⠀⠀⠀⠀⣀⡀
# ⠀⠀⠀⠀⣿⠙⣦⠀⠀⠀⠀⠀⠀⣀⣤⡶⠛⠁
# ⠀⠀⠀⠀⢻⠀⠈⠳⠀⠀⣀⣴⡾⠛⠁⣠⠂⢠⠇
# ⠀⠀⠀⠀⠈⢀⣀⠤⢤⡶⠟⠁⢀⣴⣟⠀⠀⣾
# ⠀⠀⠀⠠⠞⠉⢁⠀⠉⠀⢀⣠⣾⣿⣏⠀⢠⡇
# ⠀⠀⡰⠋⠀⢰⠃⠀⠀⠉⠛⠿⠿⠏⠁⠀⣸⠁
# ⠀⠀⣄⠀⠀⠏⣤⣤⣀⡀⠀⠀⠀⠀⠀⠾⢯⣀
# ⠀⠀⣻⠃⠀⣰⡿⠛⠁⠀⠀⠀⢤⣀⡀⠀⠺⣿⡟⠛⠁
# ⠀⡠⠋⡤⠠⠋⠀⠀⢀⠐⠁⠀⠈⣙⢯⡃⠀⢈⡻⣦
# ⢰⣷⠇⠀⠀⠀⢀⡠⠃⠀⠀⠀⠀⠈⠻⢯⡄⠀⢻⣿⣷
# ⠀⠉⠲⣶⣶⢾⣉⣐⡚⠋⠀⠀⠀⠀⠀⠘⠀⠀⡎⣿⣿⡇
# ⠀⠀⠀⠀⠀⣸⣿⣿⣿⣷⡄⠀⠀⢠⣿⣴⠀⠀⣿⣿⣿⣧
# ⠀⠀⠀⢀⣴⣿⣿⣿⣿⣿⠇⠀⢠⠟⣿⠏⢀⣾⠟⢸⣿⡇
# ⠀⠀⢠⣿⣿⣿⣿⠟⠘⠁⢠⠜⢉⣐⡥⠞⠋⢁⣴⣿⣿⠃
# ⠀⠀⣾⢻⣿⣿⠃⠀⠀⡀⢀⡄⠁⠀⠀⢠⡾ᵇʸ ᵗⁿᵏᵃ⠁
# ⠀⠀⠃⢸⣿⡇⠀⢠⣾⡇⢸⡇⠀⠀⠀⡞
# ⠀⠀⠀⠈⢿⡇⡰⠋⠈⠙⠂⠙⠢
# ⠀⠀⠀⠀⠈⢧
# Satwik@SHADOW
#
#  Windows 11 Home (25H2) aarch64
#  Snapdragon(R) X 10-core X1P64100 (10) @ 3.40 GHz
# 󰚗 Microsoft Surface Pro, 11th Edition
#  13.97 GiB / 15.61 GiB (89%)
#  349.23 GiB / 929.95 GiB (38%) - NTFS
#  378.26 GiB / 929.95 GiB (41%) - FAT32
#
# ● ● ● ● ● ● ● ●

# %% [markdown]
# ### Download and load the well-trained weights:

# %%
import urllib.request
import os

if not os.path.exists('magnet_epoch12_loss7.28e-02.pth'):
    url = 'https://github.com/ZhengPeng7/motion_magnification_learning-based/releases/download/v1.0/magnet_epoch12_loss7.28e-02.pth'
    print(f"Downloading {url}...")
    urllib.request.urlretrieve(url, 'magnet_epoch12_loss7.28e-02.pth')
    print("Download complete.")

# %%
from magnet import MagNet
from callbacks import gen_state_dict
from config import Config
from data import device


# config
config = Config()
# Load weights
weights_path = 'magnet_epoch12_loss7.28e-02.pth'
ep = int(weights_path.split('epoch')[-1].split('_')[0])
state_dict = gen_state_dict(weights_path)

model_test = MagNet().to(device)
model_test.load_state_dict(state_dict)
model_test.eval()
print("Loading weights:", weights_path)
# Out:
# Please load train_mf.txt if you want to do training.
# Loading weights: magnet_epoch12_loss7.28e-02.pth

# %% [markdown]
# # Preprocess
#
# Make the video to frameAs/frameBs/frameCs.
#
# Let's take the guitar.mp4 as an example.

# %%
import gdown
import os

# Download some example video from my google-drive or upload your own video.
# gdown.download(id='1hNZ02vnSO04FYS9jkx2OjProYHIvwdkB', output='guitar.avi', quiet=False)

if not os.path.exists('baby.avi'):
    # file_id = '1XGC2y4Lshd9aBiBxwkTuT_IA79n-WNST'
    # url = f'https://drive.google.com/uc?id={file_id}'
    # gdown.download(url, 'baby.avi', quiet=False)
    # Using simple id download
    gdown.download(id='1XGC2y4Lshd9aBiBxwkTuT_IA79n-WNST', output='baby.avi', quiet=False)

# gdown.download(id='1QGOWuR0swF7_eHharTztlkEDz0hlfmU4', output='zhiyin.mp4', quiet=False)

# %% [markdown]
# # Set VIDEO_NAME here, e.g., guitar, baby

# %%
import os
import sys
import shutil
import cv2
import subprocess
import glob

# Turn the video into frames and make them into frame_ACB format.
file_to_be_maged = 'baby.avi'   # 'guitar.avi'
video_name = file_to_be_maged.split('.')[0]
video_format = '.' + file_to_be_maged.split('.')[-1]

if not os.path.exists(video_name):
    os.makedirs(video_name)

# Extract frames
# Try using ffmpeg if available, otherwise fallback to opencv
use_ffmpeg = False
if shutil.which('ffmpeg'):
    use_ffmpeg = True
    print("Using ffmpeg to extract frames...")
    subprocess.run(['ffmpeg', '-i', file_to_be_maged, '-f', 'image2', os.path.join(video_name, '%06.png')])
else:
    print("ffmpeg not found, using opencv to extract frames...")
    vidcap = cv2.VideoCapture(file_to_be_maged)
    success, image = vidcap.read()
    count = 1
    while success:
        cv2.imwrite(os.path.join(video_name, '%06d.png' % count), image)     
        success, image = vidcap.read()
        count += 1
    vidcap.release()

# Run make_frameACB.py logic
# We can run it as a subprocess or import it if we refactored it to be callable, 
# but running as script keeps it simple for now matching the original flow
subprocess.run([sys.executable, 'make_frameACB.py', video_name])

if not os.path.exists('test_dir'):
    os.makedirs('test_dir')

dest_path = os.path.join('test_dir', video_name)
if os.path.exists(dest_path):
    shutil.rmtree(dest_path)
    
shutil.move(video_name, 'test_dir')
# Out:
# ffmpeg not found, using opencv to extract frames...
# 'test_dir\\baby'

# %% [markdown]
# ## Test

# %%
import os
import sys
import cv2
import torch
import numpy as np
from data import get_gen_ABC, unit_postprocessing, numpy2cuda, resize2d


# testsets = '+'.join(['baby', 'guitar', 'gun', 'drone', 'cattoy', 'water'][:])
for testset in [video_name]:
    dir_results = 'res_' + testset
    if not os.path.exists(dir_results):
        os.makedirs(dir_results)

    config.data_dir = 'test_dir'
    data_loader = get_gen_ABC(config, mode='test_on_'+testset)
    print('Number of test image couples:', data_loader.data_len)
    vid_size = cv2.imread(data_loader.paths[0]).shape[:2][::-1]

    # Test
    for amp in [10, 25, 50]:
        frames = []
        data_loader = get_gen_ABC(config, mode='test_on_'+testset)
        for idx_load in range(0, data_loader.data_len, data_loader.batch_size):
            if (idx_load+1) % 100 == 0:
                print('{}'.format(idx_load+1), end=', ')
            batch_A, batch_B = data_loader.gen_test()
            amp_factor = numpy2cuda(amp)
            for _ in range(len(batch_A.shape) - len(amp_factor.shape)):
                amp_factor = amp_factor.unsqueeze(-1)
            with torch.no_grad():
                y_hats = model_test(batch_A, batch_B, 0, 0, amp_factor, mode='evaluate')
            for y_hat in y_hats:
                y_hat = unit_postprocessing(y_hat, vid_size=vid_size)
                frames.append(y_hat)
                if len(frames) >= data_loader.data_len:
                    break
            if len(frames) >= data_loader.data_len:
                break
        data_loader = get_gen_ABC(config, mode='test_on_'+testset)
        frames = [unit_postprocessing(data_loader.gen_test()[0], vid_size=vid_size)] + frames

        # Make videos of framesMag
        video_dir = os.path.join(dir_results, testset)
        if not os.path.exists(video_dir):
            os.makedirs(video_dir)
        FPS = 30
        video_save_path = os.path.join(video_dir, '{}_amp{}{}'.format(testset, amp, video_format))
        out = cv2.VideoWriter(
            video_save_path,
            cv2.VideoWriter_fourcc(*'DIVX'),
            FPS, frames[0].shape[-2::-1]
        )
        for frame in frames:
            frame = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
            cv2.putText(frame, 'amp_factor={}'.format(amp), (7, 37),
                        fontFace=cv2.FONT_HERSHEY_SIMPLEX, fontScale=1, color=(0, 0, 255), thickness=2)
            out.write(frame)
        out.release()
        print('{} has been done.'.format(video_save_path))
# Out:
# Number of test image couples: 300
# 100, 200, 300, res_baby\baby\baby_amp10.avi has been done.
# 100, 200, 300, res_baby\baby\baby_amp25.avi has been done.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 32
#      30     amp_factor = amp_factor.unsqueeze(-1)
#      31 with torch.no_grad():
# ---> 32     y_hats = model_test(batch_A, batch_B, 0, 0, amp_factor, mode='evaluate')
#      33 for y_hat in y_hats:
#      34     y_hat = unit_postprocessing(y_hat, vid_size=vid_size)
#
# File c:\Users\Satwik\Documents\MSc Year 1\Q3\Computer vision\motion_magnification_learning-based\.venv\lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Satwik\Documents\MSc Year 1\Q3\Computer vision\motion_magnification_learning-based\.venv\lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\Satwik\Documents\MSc Year 1\Q3\Computer vision\motion_magnification_learning-based\magnet.py:180, in MagNet.forward(self, batch_A, batch_B, batch_C, batch_M, amp_factor, mode)
#     178 texture_B, motion_B = self.encoder(batch_B)
#     179 motion_mag = self.manipulator(motion_A, motion_B, amp_factor)
# --> 180 y_hat = self.decoder(texture_B, motion_mag)
#     181 return y_hat
#
# File c:\Users\Satwik\Documents\MSc Year 1\Q3\Computer vision\motion_magnification_learning-based\.venv\lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Satwik\Documents\MSc Year 1\Q3\Computer vision\motion_magnification_learning-based\.venv\lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\Satwik\Documents\MSc Year 1\Q3\Computer vision\motion_magnification_learning-based\magnet.py:132, in Decoder.forward(self, texture, motion)
#     129     texture = nn.functional.interpolate(texture, size=motion.shape[-2:])
#     130 x = torch.cat([texture, motion], 1)
# --> 132 x = self.resblks(x)
#     134 x = self.up(x)
#     135 x = self.cba_1(x)
#
# File c:\Users\Satwik\Documents\MSc Year 1\Q3\Computer vision\motion_magnification_learning-based\.venv\lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Satwik\Documents\MSc Year 1\Q3\Computer vision\motion_magnification_learning-based\.venv\lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\Satwik\Documents\MSc Year 1\Q3\Computer vision\motion_magnification_learning-based\.venv\lib\site-packages\torch\nn\modules\container.py:240, in Sequential.forward(self, input)
#     238 def forward(self, input):
#     239     for module in self:
# --> 240         input = module(input)
#     241     return input
#
# File c:\Users\Satwik\Documents\MSc Year 1\Q3\Computer vision\motion_magnification_learning-based\.venv\lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Satwik\Documents\MSc Year 1\Q3\Computer vision\motion_magnification_learning-based\.venv\lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\Satwik\Documents\MSc Year 1\Q3\Computer vision\motion_magnification_learning-based\magnet.py:49, in ResBlk.forward(self, x)
#      48 def forward(self, x):
# ---> 49     y = self.cba_1(x)
#      50     y = self.cba_2(y)
#      51     return y + x
#
# File c:\Users\Satwik\Documents\MSc Year 1\Q3\Computer vision\motion_magnification_learning-based\.venv\lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Satwik\Documents\MSc Year 1\Q3\Computer vision\motion_magnification_learning-based\.venv\lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\Satwik\Documents\MSc Year 1\Q3\Computer vision\motion_magnification_learning-based\magnet.py:36, in Conv2D_activa.forward(self, x)
#      34 if self.padding:
#      35     x = self.pad(x)
# ---> 36 x = self.conv2d(x)
#      37 if self.activation:
#      38     x = self.activation(x)
#
# File c:\Users\Satwik\Documents\MSc Year 1\Q3\Computer vision\motion_magnification_learning-based\.venv\lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Satwik\Documents\MSc Year 1\Q3\Computer vision\motion_magnification_learning-based\.venv\lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\Satwik\Documents\MSc Year 1\Q3\Computer vision\motion_magnification_learning-based\.venv\lib\site-packages\torch\nn\modules\conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\Satwik\Documents\MSc Year 1\Q3\Computer vision\motion_magnification_learning-based\.venv\lib\site-packages\torch\nn\modules\conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     537 if self.padding_mode != "zeros":
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# KeyboardInterrupt:

# %%
# Play the amplified video here
from glob import glob
import mediapy


video_save_paths = [file_to_be_maged] + sorted(glob(os.path.join(dir_results, testset, '*')), key=lambda x: int(x.split('amp')[-1].split('.')[0]))

video_dict = {}
for video_save_path in video_save_paths[:]:
  video_dict[video_save_path.split('/')[-1]] = mediapy.read_video(video_save_path)
mediapy.show_videos(video_dict, fps=FPS, width=250, codec='gif')
